# %% [markdown]
# # Script start

# %%
from get_file_info import *

# %%
# %load get_file_info.py
import sys
import os
import inspect
from hashlib import md5
from pathlib import Path
from functools import partial
import datetime as dt

import numpy as np
import pandas as pd
import attr
from toolz import curry

from dask import compute, delayed
import dask.threaded
import dask.multiprocessing

bllb_path = str(Path(r"../../../code/python/bllb").resolve())
sys.path.insert(0, bllb_path)
from bllb_logging import *

from bllb import pp
from pprint import pprint  #as pp

def start_log(enable=True, lvl='WARNING'):
    log = setup_logging(enable, lvl, std_lib=True)
    log.info('examinator logging started')
    return log

# %%
#### Cli.py implementation snips below
LOG_ON = True
LOG_LEVEL = "DEBUG"  #"WARNING"
log_on = LOG_ON
log_level = LOG_LEVEL
log = start_log(log_on, log_level)
dbg = log.debug
# Out:
# INFO:root:Imported standard library logging module.
# 	 Level: DEBUG
# DEBUG:root:log settings
# 	Enabled:	True
# 	Level:	DEBUG
# 	True
# INFO:root:examinator logging started

# %%
@attr.s
class daskerator(object):
    _DSCH = {
            'd': 'distributed',
            't': 'threads',
            'p': 'processes',
            's': 'synchronous'
    }
    def _get_sched(mp_type) -> str:
        if mp_type in daskerator._DSCH.keys():
            return daskerator._DSCH[mp_type]
        else:
            return mp_type
    mp_type = attr.ib(default='s', type=str, converter=_get_sched, 
                      validator=attr.validators.in_(list(_DSCH.keys()) + list(_DSCH.values())))
    sch_add = attr.ib(default='', type=str)
    @sch_add.validator
    def check_dask_opts(instance, attribute, value):
        if instance.mp_type != 'distributed' and value != '':
            raise ValueError('Only distributed dask can accept scheduler address.')
    _client = attr.ib(default=None)
    def __attrs_post_init__(self):
        if self.mp_type[0] == 'd':
            from dask.distributed import Client
            dbg("Creating distributed client object.")
            if self.sch_add == '':
                dbg("Creating new cluster on localhost.")
                self.client = Client()
            else:
                dbg(f"Existing scheduler address: {self.sch_add}")
                self.client = Client(self.sch_add)
            log.info(self.client)
    @curry
    def run_dask(self, func, iterator):
        dbg(f'Scheduler: {self.mp_type}')
        return compute(*map(delayed(func), iterator),
                       scheduler=self.mp_type)

# %%
def md5_blocks(path, blocksize=1024 * 2048) -> str:
    path = Path(path)
    if not path.is_dir():
        try:
            hasher = md5()
            with path.open('rb') as file:
                block = file.read(blocksize)
                while len(block) > 0:
                    hasher.update(block)
                    block = file.read(blocksize)
            return hasher.hexdigest()
        except Exception as error:
            log.warning(f'Error trying to hash item: {str(path)}\nError:\n{error}')
            return
    else:
        dbg(f'Item is a directory and will not be hashed.  {str(path)}')
        return

# %%
def get_stat(path, opt_md5=True, opt_pid=False) -> dict:
    path = Path(path)
    info = path.lstat()
    d = dict([
        t for t in inspect.getmembers(info)
        if not t[0].startswith('_') and not inspect.isbuiltin(t[1])
    ])
    d['path'] = path
    d['f_atime'] = dt.datetime.fromtimestamp(d['st_atime'])
    d['f_ctime'] = dt.datetime.fromtimestamp(d['st_ctime'])
    d['f_mtime'] = dt.datetime.fromtimestamp(d['st_mtime'])
    if opt_md5: 
        if not path.is_dir():
            try:
                d['md5'] = md5_blocks(path)
            except:
                log.warning(f'Could not hash item: {str(path)}')
                pass
        else:
            dbg(f'Item is a directory and will not be hashed.  {str(path)}')
    if opt_pid:
        dbg(f"working using OS pid: {os.getpid()}, opt_pid: {opt_pid}")
    return d

def path_stat(path, opt_md5=True) -> pd.DataFrame:
    get_stat2 = lambda path: get_stat(path, opt_md5)
    return pd.DataFrame([*map(get_stat2, Path(path).rglob('*'))])

def path_stat_dask(dsk, path, opt_md5=True, opt_pid=False):
    get_stat2 = lambda path: get_stat(path, opt_md5, opt_pid)
    return pd.DataFrame(dsk.run_dask(get_stat2, Path(path).rglob('*')))

# %%
def proc_paths(basepaths, mp_type='s', opt_md5=True):
    dsk = daskerator(mp_type)
    path_stat_dask2 = lambda path: path_stat_dask(dsk, path, opt_md5=True)
    df = pd.concat([*map(path_stat_dask2, basepaths)])
    if len(df):
        return df
    else:
        log.info('No results.')
        return

# %% [markdown]
# #### Script end
# Functions and scripts above
#
# Implementation and testing below

# %%
# Test stat_getter init
df = proc_paths(['.'], mp_type='t', opt_md5=False)
df
# Out:
# DEBUG:root:Scheduler: threads
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-2jeni11p
# DEBUG:root:Item is a directory and will not be hashed.  scratch/.ipynb_checkpoints
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-0x_wirpw
# DEBUG:root:Item is a directory and will not be hashed.  __pycache__
# DEBUG:root:Item is a directory and will not be hashed.  .ipynb_checkpoints
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-xtvsw556
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-fbmqevqz
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-p3ao2mmf/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-cfv9yz6u
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-xtvsw556/storage
# DEBUG:root:Item is a directory and will not be hashed.  scratch
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-2jeni11p/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-p3ao2mmf
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-bngr79vg
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-fbmqevqz/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-_x4d9r0_/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-cfv9yz6u/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-bngr79vg/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-_x4d9r0_
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space/worker-0x_wirpw/storage
# DEBUG:root:Item is a directory and will not be hashed.  dask-worker-space
#                       f_atime                    f_ctime  \
# 66 2019-03-07 15:12:40.505828  e41ea3a319115d1a5208f7d7a3f5de17        19
#
#     n_sequence_fields  n_unnamed_fields  \
# 0                  10                 3
# 1                  10                 3
# 2                  10                 3
# 3                  10                 3
# 4                  10                 3
# 5                  10                 3
# 6                  10                 3
# 7                  10                 3
# 8                  10                 3
# 9                  10                 3
# 10                 10                 3
# 11                 10                 3
# 12                 10                 3
# 13                 10                 3
# 14                 10                 3
# 15                 10                 3
# 16                 10                 3
# 17                 10                 3
# 18                 10                 3
# 19                 10                 3
# 20                 10                 3
# 21                 10                 3
# 22                 10                 3
# 23                 10                 3
# 24                 10                 3
# 25                 10                 3
# 26                 10                 3
# 27                 10                 3
# 28                 10                 3
# 29                 10                 3
# ..                ...               ...
# 37                 10                 3
# 38                 10                 3
# 39                 10                 3
# 40                 10                 3
# 41                 10                 3
# 42                 10                 3
# 43                 10                 3
# 44                 10                 3
# 45                 10                 3
# 46                 10                 3
# 47                 10                 3
# 48                 10                 3
# 49                 10                 3
# 50                 10                 3
# 51                 10                 3
# 52                 10                 3
# 53                 10                 3
# 54                 10                 3
# 55                 10                 3
# 56                 10                 3
# 57                 10                 3
# 58                 10                 3
# 59                 10                 3
# 60                 10                 3
# 61                 10                 3
# 62                 10                 3
# 63                 10                 3
# 64                 10                 3
# 65                 10                 3
# 66                 10                 3
#
#                                                  path      st_atime  \
# 0                                  .ipynb_checkpoints  1.551972e+09
# 1                                              cli.py  1.551896e+09
# 2                                             cli2.py  1.551972e+09
# 3                                   dask-worker-space  1.551999e+09
# 4                                       examinator.py  1.551803e+09
# 5                                      examinator2.py  1.551896e+09
# 6                                    get_file_info.py  1.551999e+09
# 7                                             scratch  1.551898e+09
# 8                                           script.py  1.551131e+09
# 9                                      test_joblib.py  1.551491e+09
# 10                                     Untitled.ipynb  1.551999e+09
# 11                                        __init__.py  1.550862e+09
# 12                                        __pycache__  1.551972e+09
# 13               .ipynb_checkpoints/cli-checkpoint.py  1.551656e+09
# 14              .ipynb_checkpoints/cli2-checkpoint.py  1.551903e+09
# 15        .ipynb_checkpoints/examinator-checkpoint.py  1.551657e+09
# 16     .ipynb_checkpoints/get_file_info-checkpoint.py  1.551972e+09
# 17        .ipynb_checkpoints/scratch-checkpoint.ipynb  1.551655e+09
# 18            .ipynb_checkpoints/script-checkpoint.py  1.551131e+09
# 19       .ipynb_checkpoints/test_joblib-checkpoint.py  1.551491e+09
# 20       .ipynb_checkpoints/Untitled-checkpoint.ipynb  1.551972e+09
# 21                      dask-worker-space/global.lock  1.551999e+09
# 22                       dask-worker-space/purge.lock  1.551999e+09
# 23                  dask-worker-space/worker-0x_wirpw  1.551998e+09
# 24          dask-worker-space/worker-0x_wirpw.dirlock  1.551999e+09
# 25                  dask-worker-space/worker-2jeni11p  1.551999e+09
# 26          dask-worker-space/worker-2jeni11p.dirlock  1.551999e+09
# 27                  dask-worker-space/worker-bngr79vg  1.551998e+09
# 28          dask-worker-space/worker-bngr79vg.dirlock  1.551999e+09
# 29                  dask-worker-space/worker-cfv9yz6u  1.551999e+09
# ..                                                ...           ...
# 37                  dask-worker-space/worker-_x4d9r0_  1.551999e+09
# 38          dask-worker-space/worker-_x4d9r0_.dirlock  1.551999e+09
# 39          dask-worker-space/worker-0x_wirpw/storage  1.551998e+09
# 40          dask-worker-space/worker-2jeni11p/storage  1.551999e+09
# 41          dask-worker-space/worker-bngr79vg/storage  1.551998e+09
# 42          dask-worker-space/worker-cfv9yz6u/storage  1.551999e+09
# 43          dask-worker-space/worker-fbmqevqz/storage  1.551998e+09
# 44          dask-worker-space/worker-p3ao2mmf/storage  1.551999e+09
# 45          dask-worker-space/worker-xtvsw556/storage  1.551998e+09
# 46          dask-worker-space/worker-_x4d9r0_/storage  1.551999e+09
# 47                         scratch/.ipynb_checkpoints  1.551897e+09
# 48                         scratch/asyncio_example.py  1.551130e+09
# 49                                scratch/ex_async.py  1.551299e+09
# 50                            scratch/loguru_issue.py  1.551405e+09
# 51                              scratch/scratch.ipynb  1.551898e+09
# 52                                  scratch/test_q.py  1.551197e+09
# 53                          scratch/test_threading.py  1.551201e+09
# 54  scratch/.ipynb_checkpoints/asyncio_example-che...  1.551130e+09
# 55  scratch/.ipynb_checkpoints/ex_async-checkpoint.py  1.551285e+09
# 56  scratch/.ipynb_checkpoints/loguru_issue-checkp...  1.551405e+09
# 57  scratch/.ipynb_checkpoints/scratch-checkpoint....  1.551803e+09
# 58    scratch/.ipynb_checkpoints/test_q-checkpoint.py  1.551197e+09
# 59  scratch/.ipynb_checkpoints/test_threading-chec...  1.551201e+09
# 60              __pycache__/examinator.cpython-36.pyc  1.551560e+09
# 61              __pycache__/examinator.cpython-37.pyc  1.551896e+09
# 62              __pycache__/examinator.cpython-38.pyc  1.551477e+09
# 63             __pycache__/examinator2.cpython-36.pyc  1.551901e+09
# 64             __pycache__/examinator2.cpython-37.pyc  1.551896e+09
# 65           __pycache__/get_file_info.cpython-36.pyc  1.551903e+09
# 66           __pycache__/get_file_info.cpython-37.pyc  1.551972e+09
#
#             st_atime_ns  ...  st_dev  st_gid    st_ino  st_mode      st_mtime  \
# 0   1551971906182167400  ...     107       0  35489000    16895  1.551972e+09
# 1   1551896490964836500  ...     107       0  35489001    33261  1.551896e+09
# 2   1551972340924382300  ...     107       0  35489002    33261  1.551972e+09
# 3   1551998843564115800  ...     107       0  35488993    16895  1.551999e+09
# 4   1551802812639982700  ...     107       0  35489004    33261  1.551803e+09
# 5   1551896445499000000  ...     107       0  35489005    33261  1.551896e+09
# 6   1551999156758176800  ...     107       0  35489006    33261  1.551999e+09
# 7   1551898180400975800  ...     107       0  35489007    16895  1.551898e+09
# 8   1551130733820684200  ...     107       0  35489008    33261  1.551131e+09
# 9   1551490946730578400  ...     107       0  35489009    33261  1.551491e+09
# 10  1551999410646386700  ...     107       0  35489010    33261  1.551999e+09
# 11  1550862111046862100  ...     107       0  35489011    33261  1.550862e+09
# 12  1551971560513823200  ...     107       0  35489012    16895  1.551972e+09
# 13  1551656317731657900  ...     107       0  35502209    33261  1.551656e+09
# 14  1551902952337043200  ...     107       0  35502210    33261  1.551903e+09
# 15  1551656541497557700  ...     107       0  35502211    33261  1.551657e+09
# 16  1551971556407878400  ...     107       0  35502212    33261  1.551972e+09
# 17  1551655431472048900  ...     107       0  35502213    33261  1.551655e+09
# 18  1551130733820684200  ...     107       0  35502214    33261  1.551131e+09
# 19  1551490946730578400  ...     107       0  35502215    33261  1.551491e+09
# 20  1551971906174169500  ...     107       0  35502216    33261  1.551972e+09
# 21  1551998843486054800  ...     107       0  35502152    33261  1.551999e+09
# 22  1551998843456058000  ...     107       0  35502154    33261  1.551999e+09
# 23  1551998380381181100  ...     107       0  35801141    16895  1.551998e+09
# 24  1551998843444087000  ...     107       0  35801144    33261  1.551999e+09
# 25  1551998843485053300  ...     107       0  35919804    16895  1.551999e+09
# 26  1551998843476064000  ...     107       0  35919807    33261  1.551999e+09
# 27  1551998380375182200  ...     107       0  35801139    16895  1.551998e+09
# 28  1551998843448086000  ...     107       0  35801142    33261  1.551999e+09
# 29  1551998843496054000  ...     107       0  35919806    16895  1.551999e+09
# ..                  ...  ...     ...     ...       ...      ...           ...
# 37  1551998843478056500  ...     107       0  35919803    16895  1.551999e+09
# 38  1551998843470053800  ...     107       0  35919805    33261  1.551999e+09
# 39  1551998380381181100  ...     107       0  35801147    16895  1.551998e+09
# 40  1551998843485053300  ...     107       0  35919812    16895  1.551999e+09
# 41  1551998380375182200  ...     107       0  35801145    16895  1.551998e+09
# 42  1551998843496054000  ...     107       0  35919815    16895  1.551999e+09
# 43  1551998380424179100  ...     107       0  35801152    16895  1.551998e+09
# 44  1551998843499057300  ...     107       0  35919816    16895  1.551999e+09
# 45  1551998380369180400  ...     107       0  35801143    16895  1.551998e+09
# 46  1551998843478056500  ...     107       0  35919809    16895  1.551999e+09
# 47  1551896621901268500  ...     107       0  35502253    16895  1.551897e+09
# 48  1551129791252617800  ...     107       0  35502254    33261  1.551130e+09
# 49  1551298887154701600  ...     107       0  35502255    33261  1.551299e+09
# 50  1551404547127730700  ...     107       0  35502256    33261  1.551405e+09
# 51  1551898180358976000  ...     107       0  35502257    33261  1.551898e+09
# 52  1551196975092119600  ...     107       0  35502258    33261  1.551197e+09
# 53  1551201434075148200  ...     107       0  35502259    33261  1.551201e+09
# 54  1551129791252617800  ...     107       0  35502267    33261  1.551130e+09
# 55  1551285085650661100  ...     107       0  35502268    33261  1.551285e+09
# 56  1551404547127730700  ...     107       0  35502269    33261  1.551405e+09
# 57  1551802813081000000  ...     107       0  35502270    33261  1.551896e+09
# 58  1551196975092119600  ...     107       0  35502271    33261  1.551197e+09
# 59  1551201434075148200  ...     107       0  35502272    33261  1.551201e+09
# 60  1551559812751339600  ...     107       0  35502279    33261  1.551560e+09
